# %%
from minigrid.core.constants import OBJECT_TO_IDX, IDX_TO_OBJECT

import gymnasium as gym

import pygame
# Out:
# d:\Study\Personal\Projects\LLMaE-PPO\.venv\Lib\site-packages\pygame\pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists

# %%
class ObservationParser:
    def __init__(self):
        self.OBJECT_TO_IDX = {
            "unseen": 0,
            "empty": 1,
            "wall": 2,
            "floor": 3,
            "door": 4,
            "key": 5,
            "ball": 6,
            "box": 7,
            "goal": 8,
            "lava": 9,
            "agent": 10,
        }

        self.IDX_TO_OBJECT = {v: k for k, v in self.OBJECT_TO_IDX.items()}

        self.DIR_TO_STR = {0: "right", 1: "down", 2: "left", 3: "up"}

        self.is_open_door = False

    def parse_observation(self, obs):
        """Parse the observation to detailed text with spatial info."""
        if isinstance(obs, dict) and "image" in obs:
            image = obs["image"]
        else:
            image = obs

        h, w, _ = image.shape

        agent_pos = (w // 2, h - 1)  # Agent is at the bottom center of the view

        # get observation channels
        obj_grid = image[:, :, 0]  # Object types
        state_grid = image[:, :, 2]  # State types

        # get agent direction
        agent_dir_idx = obs["direction"]

        return self._build_spatial_description(
            obj_grid, state_grid, agent_pos, agent_dir_idx
        )

    def _build_spatial_description(
        self, obj_grid, state_grid, agent_pos, agent_dir_idx
    ):
        """Build a detailed spatial description of the observation."""

        object_info = []
        h, w = obj_grid.shape

        for i in range(h):
            for j in range(w):
                obj_idx = obj_grid[i, j]

                # skip unseen, empty, wall
                if obj_idx in [0, 1]:
                    continue
                # skip agent position
                if agent_pos == (i, j):
                    continue
                obj_type = self.IDX_TO_OBJECT.get(obj_idx)

                if obj_type in ["key", "door", "goal"]:
                    state = state_grid[i, j]

                    # Get relative position from agent's perspective
                    relative_pos = self._get_relative_position(
                        agent_pos, (i, j), agent_dir_idx
                    )

                    info = {
                        "type": obj_type,
                        "relative_position": relative_pos,
                        "distance": abs(i - agent_pos[0]) + abs(j - agent_pos[1]),
                    }

                    if obj_type == "door":
                        info["is_open"] = state == 0

                    object_info.append(info)

        carrying = "key" if obj_grid[agent_pos] == 5 else "nothing"
        # carrying = 'nothing'

        front = (agent_pos[0], agent_pos[1] - 1)

        is_wall_in_front = obj_grid[front] == self.OBJECT_TO_IDX["wall"]

        return self._format_description(object_info, carrying, is_wall_in_front)

    def _get_relative_position(self, agent_pos, obj_pos, agent_dir):
        """Get object position relative to agent's facing direction"""

        # print(f"Agent pos: {agent_pos}, Object pos: {obj_pos}, Agent dir: {agent_dir}")

        # Calculate raw offset
        dy = agent_pos[1] - obj_pos[1]  # alway postive or equal to 0
        dx = obj_pos[0] - agent_pos[0]  # postive is right, negative is left

        # Convert to description
        position_parts = []

        if dx == 0 and dy == 1:
            return "is right infront"

        if dy > 0:  # Object is to the right
            position_parts.append(f"{dy} steps forward")
        if dx > 0:
            position_parts.append(f"{dx} steps right")
        if dx < 0:  # Object is to the left
            position_parts.append(f"{-dx} steps left")

        if not position_parts:
            return "at agent position"

        return " and ".join(position_parts)

    def _format_description(self, objects_info, carrying, is_wall_in_front):
        """Format the complete description"""

        parts = []
        if is_wall_in_front:
            parts.append("Agent (wall in front)")
        else:
            parts.append("Agent (clear path ahead)")

        # Objects in view
        if objects_info:
            obj_descriptions = []

            # Sort by distance for consistent ordering
            objects_info.sort(key=lambda x: x["distance"])

            for obj in objects_info:
                if obj["type"] == "door":
                    state = "open" if obj["is_open"] else "closed"
                    if state == "open":
                        self.is_open_door = True
                    desc = f"{state} door {obj['relative_position']}"
                else:
                    desc = f"{obj['type']} {obj['relative_position']}"
                obj_descriptions.append(desc)

            parts.append(f"sees: {'; '.join(obj_descriptions)}")
        else:
            parts.append("sees: nothing")

        # Carrying status
        parts.append(f"carrying: {carrying}")

        return ", ".join(parts)

# %%
ACTIONS = {
    pygame.K_LEFT: 0,  # Turn left
    pygame.K_RIGHT: 1,  # Turn right
    pygame.K_UP: 2,  # Move forward
    pygame.K_SPACE: 3,  # Pick up
    pygame.K_d: 4,  # Drop
    pygame.K_RETURN: 5,  # Toggle (open door)
    pygame.K_q: 6,  # Done
}

parser = ObservationParser()


def main():
    env = gym.make("MiniGrid-DoorKey-8x8-v0", render_mode="human")
    obs, _ = env.reset(seed=1)

    running = True
    while running:
        env.render()

        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                running = False
                env.close()
                break

            elif event.type == pygame.KEYDOWN:
                if event.key in ACTIONS:
                    action = ACTIONS[event.key]
                    if parser.is_open_door and action == 2:
                        print("Agent went through the door!")
                    obs, reward, terminated, truncated, info = env.step(action)
                    print(
                        f"Action: {action}, Reward: {reward}, Done: {terminated or truncated}"
                    )
                    image = obs["image"]
                    h, w = image.shape[:2]
                    # print(f"Agent facing: {obs['direction']}")
                    # print(f"Observation:\n {obs['image'][:, :, 0]}")  # Print object types
                    print(f"Description: {parser.parse_observation(obs)}")
                    if terminated or truncated:
                        print("Episode finished. Resetting...")
                        obs, _ = env.reset(seed=1)

    pygame.quit()


main()
# Out:
# Action: 2, Reward: 0, Done: False
# Description: Agent (clear path ahead), sees: key 4 steps forward and 1 steps right; closed door 4 steps forward and 2 steps right, carrying: nothing
# Action: 2, Reward: 0, Done: False
# Description: Agent (clear path ahead), sees: key 3 steps forward and 1 steps right; closed door 3 steps forward and 2 steps right, carrying: nothing
# Action: 2, Reward: 0, Done: False
# Description: Agent (clear path ahead), sees: key 2 steps forward and 1 steps right; closed door 2 steps forward and 2 steps right, carrying: nothing
# Action: 2, Reward: 0, Done: False
# Description: Agent (clear path ahead), sees: key 1 steps forward and 1 steps right; closed door 1 steps forward and 2 steps right, carrying: nothing
# Action: 1, Reward: 0, Done: False
# Description: Agent (clear path ahead), sees: key 1 steps forward and 1 steps left; closed door 2 steps forward and 1 steps left, carrying: nothing
# Action: 2, Reward: 0, Done: False
# Description: Agent (wall in front), sees: key 1 steps left; closed door 1 steps forward and 1 steps left, carrying: nothing
# Action: 1, Reward: 0, Done: False
# Description: Agent (clear path ahead), sees: nothing, carrying: nothing
# Action: 1, Reward: 0, Done: False
# Description: Agent (clear path ahead), sees: key 1 steps right, carrying: nothing
# Action: 2, Reward: 0, Done: False
# Description: Agent (wall in front), sees: nothing, carrying: nothing
# Action: 1, Reward: 0, Done: False
# Description: Agent (clear path ahead), sees: key 1 steps forward and 1 steps right; closed door 1 steps forward and 2 steps right, carrying: nothing
# Action: 0, Reward: 0, Done: False
# Description: Agent (wall in front), sees: nothing, carrying: nothing
# Action: 1, Reward: 0, Done: False
# Description: Agent (clear path ahead), sees: key 1 steps forward and 1 steps right; closed door 1 steps forward and 2 steps right, carrying: nothing
# Action: 2, Reward: 0, Done: False
# Description: Agent (wall in front), sees: key 1 steps right; closed door 2 steps right, carrying: nothing
# Action: 1, Reward: 0, Done: False
# Description: Agent (clear path ahead), sees: key is right infront; closed door 2 steps forward, carrying: nothing
# Action: 3, Reward: 0, Done: False
# Description: Agent (clear path ahead), sees: closed door 2 steps forward, carrying: key
# Action: 2, Reward: 0, Done: False
# Description: Agent (clear path ahead), sees: closed door is right infront, carrying: key
# Action: 2, Reward: 0, Done: False
# Description: Agent (clear path ahead), sees: closed door is right infront, carrying: key
# Action: 5, Reward: 0, Done: False
# Description: Agent (clear path ahead), sees: open door is right infront, carrying: key
# Agent went through the door!
# Action: 2, Reward: 0, Done: False
# Description: Agent (clear path ahead), sees: nothing, carrying: key
# Agent went through the door!
# Action: 2, Reward: 0, Done: False
# Description: Agent (clear path ahead), sees: nothing, carrying: key
# Agent went through the door!
# Action: 2, Reward: 0, Done: False
# Description: Agent (clear path ahead), sees: nothing, carrying: key
# Action: 1, Reward: 0, Done: False
# Description: Agent (clear path ahead), sees: open door 2 steps right; goal 5 steps forward and 1 steps left, carrying: key
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[67], line 45
#      41                         obs, _ = env.reset(seed=1)
#      43     pygame.quit()
# ---> 45 main()
#
# Cell In[67], line 19, in main()
#      17 running = True
#      18 while running:
# ---> 19     env.render()
#      21     for event in pygame.event.get():
#      22         if event.type == pygame.QUIT:
#
# File d:\Study\Personal\Projects\LLMaE-PPO\.venv\Lib\site-packages\gymnasium\wrappers\common.py:409, in OrderEnforcing.render(self)
#     404 if not self._disable_render_order_enforcing and not self._has_reset:
#     405     raise ResetNeeded(
#     406         "Cannot call `env.render()` before calling `env.reset()`, if this is an intended action, "
#     407         "set `disable_render_order_enforcing=True` on the OrderEnforcer wrapper."
#     408     )
# --> 409 return super().render()
#
# File d:\Study\Personal\Projects\LLMaE-PPO\.venv\Lib\site-packages\gymnasium\core.py:337, in Wrapper.render(self)
#     335 def render(self) -> RenderFrame | list[RenderFrame] | None:
#     336     """Uses the :meth:`render` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 337     return self.env.render()
#
# File d:\Study\Personal\Projects\LLMaE-PPO\.venv\Lib\site-packages\gymnasium\wrappers\common.py:303, in PassiveEnvChecker.render(self)
#     301     return env_render_passive_checker(self.env)
#     302 else:
# --> 303     return self.env.render()
#
# File d:\Study\Personal\Projects\LLMaE-PPO\.venv\Lib\site-packages\minigrid\minigrid_env.py:781, in MiniGridEnv.render(self)
#     779     self.window.blit(bg, (0, 0))
#     780     pygame.event.pump()
# --> 781     self.clock.tick(self.metadata["render_fps"])
#     782     pygame.display.flip()
#     784 elif self.render_mode == "rgb_array":
#
# KeyboardInterrupt:

# %%
class PromptManager:
    """Manages prompts for the LLM"""

    def __init__(self):
        self.system_prompt = """You are an expert agent navigating a grid world in the DoorKey-8x8 environment.

ENVIRONMENT RULES:
- You control an agent that can move in a grid world
- You must: 1) Pick up the key, 2) Unlock the door, 3) Reach the goal
- You can only move to empty spaces or through open doors
- You cannot move through walls or closed doors or keys
- Remember you have to be in front of the object to interact with it
- If you don't see an object in your view, you should turn left/right or move to see more of the grid world
- If you already went through a door once, you must not go through it again. Instead you should explore by turning left or right or going forward to find the goal

Your goal is to:
1. Find and pick up the key
2. Use the key to unlock the door
3. Reach the goal

ACTIONS:
- 0 = Turn left (rotate 90° counter-clockwise)
- 1 = Turn right (rotate 90° clockwise)
- 2 = Move forward one cell
- 3 = Pick up key (must be at key position)
- 5 = Toggle door (must be at door position with key)

Think step by step:
1. What is my current state?
2. What is my immediate objective?
3. What action gets me closer to that objective?

CRITICAL: You have to be in front of the objects to interact with it. You can not 1 step away from it to interact with it!

Respond in this format:
Reasoning: <your_reasoning>
Action: <action_number>."""

        self.few_shot_examples = """
Example 1:
State: Agent (clear path ahead), sees: key is right infrond; closed door 3 steps forward and 3 steps left, carrying: nothing
Reasoning: I see the key and it is directly in front of me. I should pick it up.
Action: 3

Example 2:
State:   Agent (wall in front), sees: closed door 1 steps forward and 3 steps left, carrying: key
Reasoning: I have the key I should go to the door. But the wall is blocking my path to the key. So I should turn left. 
Action: 0

Example 3:
State: Agent has just gone through a door once, Agent (clear path ahead), sees: open door 2 steps forward, carrying: key
Reasoning: I already opened the door, and went through it once, so I should not go through it again. Instead I should turn left or right to find the goal.
Action: 1

Example 4:
State: Agent (clear path ahead), sees: door 1 steps forward and 1 steps left, carrying: key
Reasoning: I see the door, but it is not in front of me, so I should prioritize going forward to reach it.
Action: 0
"""

    def create_query_prompt(self, state_description, is_went_through_door):
        """Create prompt for action query"""
        # prompt_parts = []
        # prompt_parts.append(f"\nCurrent state: {state_description}")
        print(f"Is agent went through door: {is_went_through_door}")
        if is_went_through_door == True:
            return f"\nCurrent state: Agent has just gone through a door once, {state_description}"
        return f"\nCurrent state: {state_description}"

# %%
class Agent:
    def __init__(self, llm_interface, env, prompt_manager, obs_parser):
        self.llm = llm_interface
        self.env = env
        self.prompt_manager = prompt_manager or PromptManager()
        self.obs_parser = obs_parser or ObservationParser()
        self.is_went_through_door = False

    def get_action(self, obs) -> int:
        """Get action from LLM given observation"""
        # Convert observation to text
        state_desc = self.obs_parser.parse_observation(obs)

        # Check cache
        # if cache in self.action_cache:
        #     return self.action_cache[cache]

        # Create prompt
        prompt = self.prompt_manager.create_query_prompt(
            state_desc, self.is_went_through_door
        )

        # Query LLM
        try:
            print(f"Querying LLM with state: {state_desc}")

            # print(f"Prompt: {prompt}")

            response = self.llm.query(
                prompt, system_prompt=self.prompt_manager.system_prompt
            )

            print(f"Response: {response}")

            # Parse action from response
            action = self._parse_action(response)

            return action

        except Exception as e:
            print(f"LLM query failed: {e}")

    def _parse_action(self, response):
        """Parse action number from LLM response"""
        # Extract first number from response
        import re

        # Action: number
        numbers = re.findall(r"Action:\s*(\d+)", response)
        print(f"Numbers: {numbers}")
        if numbers:
            action = int(numbers[0])
            # Validate action
            if 0 <= action < self.env.action_space.n:
                return action
        import random

        # Fallback to forward movement
        return random.choice([0, 1, 2])

    def generate_trajectory(self, max_steps: int = 50):
        """Generate a single trajectory"""

        obs = self.env.reset()[0]

        actions = []
        rewards = []
        next_observations = []
        dones = []
        infos = []

        total_reward = 0
        done = False
        self.obs_parser.is_open_door = False
        for step in range(max_steps):
            self.env.render()
            # Get action from LLM
            action = self.get_action(obs)
            if (
                self.obs_parser.is_open_door
                and action == 2
                and not self.is_went_through_door
            ):
                print("Agent went through the door!")

                self.is_went_through_door = True

            # Execute action
            next_obs, reward, terminated, truncated, info = self.env.step(action)
            done = terminated or truncated

            actions.append(action)
            rewards.append(reward)
            next_observations.append(
                next_obs["image"] if isinstance(next_obs, dict) else next_obs
            )
            dones.append(done)
            infos.append(info)

            total_reward += reward
            obs = next_obs

            if done:
                break

# %%
import gymnasium as gym
import openai
import re
from minigrid.wrappers import FlatObsWrapper
from openai import OpenAI
import os
import minigrid
import pprint
import json
import dotenv
import numpy as np
from dotenv import load_dotenv
from abc import ABC, abstractmethod


class LLMInterface(ABC):
    """Abstract base class for LLM interfaces"""

    @abstractmethod
    def query(self, prompt: str, system_prompt: str = None) -> str:
        pass


# Load environment variables from .env file
load_dotenv()


class OpenAIInterface(LLMInterface):
    """OpenAI API interface"""

    def __init__(self, model: str = "gpt-4"):
        self.client = OpenAI(
            api_key=os.getenv("OPENAI_API_KEY"), base_url=os.getenv("OPENAI_BASE_URL")
        )
        self.model = model

    def query(self, prompt: str, system_prompt: str = None) -> str:
        messages = []
        if system_prompt:
            messages.append({"role": "system", "content": system_prompt})
        messages.append({"role": "user", "content": prompt})

        response = self.client.chat.completions.create(
            model=self.model,
            messages=messages,
            temperature=0.1,  # Low temperature for consistency
            max_tokens=200,
        )

        return response.choices[0].message.content

# %%
env = gym.make("MiniGrid-DoorKey-8x8-v0", render_mode="human")

llm = OpenAIInterface(model="meta-llama/llama-3.3-70b-instruct")

agent = Agent(
    llm_interface=llm,
    env=env,
    prompt_manager=PromptManager(),
    obs_parser=ObservationParser(),
)

# %%
agent.generate_trajectory()
# Out:
# Is agent went through door: False
# Querying LLM with state: Agent (clear path ahead), sees: closed door 2 steps forward and 3 steps left, carrying: nothing
# Response: Reasoning: The agent's current state is that it has a clear path ahead, sees a closed door 2 steps forward and 3 steps left, and is not carrying anything. The immediate objective is to find the key, as the agent cannot unlock the door without it. Since the agent does not see the key, it needs to explore its surroundings to locate it. The agent should move forward to get closer to the area where the door is, which may help in finding the key or getting a better view of the surroundings.
#
# Action: 2.
# Numbers: ['2']
# Is agent went through door: False
# Querying LLM with state: Agent (wall in front), sees: closed door 1 steps forward and 3 steps left, carrying: nothing
# Response: Reasoning: The agent is currently facing a wall and sees a closed door 1 step forward and 3 steps left. The immediate objective is to explore the environment and find the key. Since the agent cannot move through the wall, it needs to turn to face the closed door or explore other parts of the grid world. Turning left or right will allow the agent to see more of the environment and potentially find the key or an open path.
#
# Action: 0.
# Numbers: ['0']
# Is agent went through door: False
# Querying LLM with state: Agent (clear path ahead), sees: closed door 3 steps forward and 1 steps right; key 5 steps forward, carrying: nothing
# Response: Reasoning: My current state is that I have a clear path ahead, and I see a closed door 3 steps forward and 1 step right, as well as a key 5 steps forward. My immediate objective is to pick up the key, as I need it to unlock the door. To get closer to the key, I should move forward.
#
# Action: 2.
# Numbers: ['2']
# Is agent went through door: False
# Querying LLM with state: Agent (clear path ahead), sees: closed door 2 steps forward and 1 steps right; key 4 steps forward, carrying: nothing
# Response: Reasoning: My current state is that I have a clear path ahead, and I see a closed door 2 steps forward and 1 step to the right, as well as a key 4 steps forward. My immediate objective is to pick up the key, as I need it to unlock the door. To achieve this, I should move forward to get closer to the key. Since the key is 4 steps forward, I will start by moving forward.
#
# Action: 2.
# Numbers: ['2']
# Is agent went through door: False
# Querying LLM with state: Agent (clear path ahead), sees: closed door 1 steps forward and 1 steps right; key 3 steps forward, carrying: nothing
# Response: Reasoning: My current state is that I have a clear path ahead, and I see a closed door 1 step forward and 1 step to the right, and a key 3 steps forward. My immediate objective is to pick up the key, as I need it to unlock the door. To achieve this, I need to move forward to reach the key. Since the key is 3 steps forward, I should start by moving forward.
#
# Action: 2.
# Numbers: ['2']
# Is agent went through door: False
# Querying LLM with state: Agent (clear path ahead), sees: closed door 1 steps right; key 2 steps forward, carrying: nothing
# Response: Reasoning: My current state is that I have a clear path ahead, I see a closed door to my right, and I see the key 2 steps forward. My immediate objective is to pick up the key, as I need it to unlock the door. To achieve this, I need to move forward to reach the key. Since the key is 2 steps forward, I will move forward one step at a time to ensure I don't miss it.
#
# Action: 2.
# Numbers: ['2']
# Is agent went through door: False
# Querying LLM with state: Agent (clear path ahead), sees: key is right infront, carrying: nothing
# Response: Reasoning: The agent's current state is that it has a clear path ahead and can see the key right in front of it. The immediate objective is to pick up the key, as it is necessary to unlock the door and ultimately reach the goal. Since the key is directly in front of the agent, the action that gets the agent closer to this objective is to move forward and pick up the key. However, according to the action definitions, the agent must first move to the key's position and then pick it up.
#
# Action: 2.
# Numbers: ['2']
# Is agent went through door: False
# Querying LLM with state: Agent (clear path ahead), sees: key is right infront, carrying: nothing
# Response: Reasoning: The agent's current state is that it has a clear path ahead and sees the key right in front of it. The immediate objective is to pick up the key, as it is necessary to unlock the door and ultimately reach the goal. Since the key is directly in front of the agent, the action that gets the agent closer to this objective is to pick up the key.
#
# Action: 3.
# Numbers: ['3']
# Is agent went through door: False
# Querying LLM with state: Agent (clear path ahead), sees: nothing, carrying: key
# Response: Reasoning: Since I'm already carrying the key, my immediate objective is to find the door to unlock it. However, I don't see the door in my current view. To find the door, I need to explore my surroundings. The best course of action would be to move forward and see if I can find the door or any other objects in my path.
#
# Action: 2.
# Numbers: ['2']
# Is agent went through door: False
# Querying LLM with state: Agent (wall in front), sees: nothing, carrying: key
# Response: Reasoning: Since the agent is facing a wall and cannot move forward, the immediate objective is to change direction to explore the grid world and find the door to unlock it. The agent is already carrying the key, so the next step is to find the door.
#
# Action: 0.
# Numbers: ['0']
# Is agent went through door: False
# Querying LLM with state: Agent (clear path ahead), sees: nothing, carrying: key
# Response: Reasoning: Since I'm already carrying the key, my immediate objective is to find the door to unlock it. However, I don't see the door in my current view. To find the door, I need to explore my surroundings. The best course of action is to move forward and see if I can find the door or any other objects.
#
# Action: 2.
# Numbers: ['2']
# Is agent went through door: False
# Querying LLM with state: Agent (wall in front), sees: nothing, carrying: key
# Response: Reasoning: Since the agent is facing a wall and cannot move forward, the immediate objective is to change direction to explore the grid world and find the door to unlock it. The agent is already carrying the key, so the next step is to find the door. To do this, the agent needs to turn either left or right to potentially see more of the environment and find a path forward.
#
# Action: 0.
# Numbers: ['0']
# Is agent went through door: False
# Querying LLM with state: Agent (clear path ahead), sees: closed door 2 steps forward and 2 steps left, carrying: key
# Response: Reasoning: Since I am already carrying the key, my immediate objective is to unlock the door. To do this, I need to be in front of the door. The door is 2 steps forward and 2 steps left of my current position. However, since I can only move forward one cell at a time and I need to be directly in front of the door to interact with it, I should first move forward to get closer to the door.
#
# Action: 2.
# Numbers: ['2']
# Is agent went through door: False
# Querying LLM with state: Agent (clear path ahead), sees: closed door 1 steps forward and 2 steps left, carrying: key
# Response: Reasoning: Since I am already carrying the key, my immediate objective is to unlock the door. The door is 1 step forward and 2 steps left, which means I need to move forward to get in front of the door to interact with it.
#
# Action: 2.
# Numbers: ['2']
# Is agent went through door: False
# Querying LLM with state: Agent (clear path ahead), sees: closed door 2 steps left, carrying: key
# Response: Reasoning: I have the key and I see a closed door 2 steps to my left. My immediate objective is to unlock the door. To unlock the door, I need to be in front of it. Since I'm currently not in front of the door, I need to move towards it. However, I should move to the position right in front of the door to interact with it.
#
# Action: 0.
# Numbers: ['0']
# Is agent went through door: False
# Querying LLM with state: Agent (clear path ahead), sees: closed door 2 steps forward, carrying: key
# Response: Reasoning: I have the key and I see a closed door 2 steps forward. My immediate objective is to unlock the door. To unlock the door, I need to be in front of it and then toggle it. Since I'm currently 2 steps away, I need to move forward to get closer to the door.
#
# Action: 2.
# Numbers: ['2']
# Is agent went through door: False
# Querying LLM with state: Agent (clear path ahead), sees: closed door is right infront, carrying: key
# Response: Reasoning: Since the agent is already carrying the key and is in front of the closed door, the immediate objective is to unlock the door to progress further. The agent must use the key to unlock the door.
#
# Action: 5.
# Numbers: ['5']
# Is agent went through door: False
# Querying LLM with state: Agent (clear path ahead), sees: open door is right infront; goal 4 steps forward and 3 steps right, carrying: key
# Response: Reasoning: Since I already have the key and the door in front of me is open, my immediate objective is to reach the goal. The goal is 4 steps forward and 3 steps right from my current position. However, I need to move forward first to get closer to the goal, and then I can turn right to align myself with the goal.
#
# Action: 2.
# Numbers: ['2']
# Agent went through the door!
# Is agent went through door: True
# Querying LLM with state: Agent (clear path ahead), sees: goal 3 steps forward and 3 steps right, carrying: key
# Response: Reasoning: Since the agent has already gone through a door once and now sees the goal, the immediate objective is to reach the goal. The agent is carrying the key, which means it has already completed the tasks of finding and picking up the key and unlocking the door. Given that the agent sees the goal 3 steps forward and 3 steps right, it needs to move in a way that gets it closer to the goal without going through the door again. The most direct path would involve moving forward and then turning to move to the right to align with the goal.
#
# Action: 2.
# Numbers: ['2']
# Is agent went through door: True
# Querying LLM with state: Agent (clear path ahead), sees: goal 2 steps forward and 3 steps right, carrying: key
# Response: Reasoning: Since the agent has already gone through a door once and should not go through it again, and the goal is in sight, the immediate objective is to reach the goal. The agent has a clear path ahead and is carrying the key, which means the door that was previously locked is now open. The goal is 2 steps forward and 3 steps right, so the agent needs to move forward and then turn to move to the right to reach the goal.
#
# Action: 2.
# Numbers: ['2']
# Is agent went through door: True
# Querying LLM with state: Agent (clear path ahead), sees: goal 1 steps forward and 3 steps right, carrying: key
# Response: Reasoning: Since the agent has already gone through a door once and now sees the goal, the immediate objective is to reach the goal. The goal is 1 step forward and 3 steps right, which means the agent needs to move forward and then turn right to align itself with the goal. However, since the agent can only move to empty spaces and the goal is within sight, the agent should move forward first to get closer to the goal.
#
# Action: 2.
# Numbers: ['2']
# Is agent went through door: True
# Querying LLM with state: Agent (wall in front), sees: goal 3 steps right, carrying: key
# Response: Reasoning: Since the agent has already gone through a door once and cannot go through it again, and there is a wall in front of the agent, the agent must explore the surroundings to reach the goal. The goal is 3 steps to the right, which means the agent needs to move in that direction to reach it. However, since the agent cannot move through the wall in front, it needs to turn to face the direction where the goal is visible and then move towards it.
#
# Action: 1.
# Numbers: ['1']
# Is agent went through door: True
# Querying LLM with state: Agent (clear path ahead), sees: goal 3 steps forward; open door 3 steps right, carrying: key
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 agent.generate_trajectory()
#
# Cell In[83], line 79, in Agent.generate_trajectory(self, max_steps)
#      77 self.env.render()
#      78 # Get action from LLM
# ---> 79 action = self.get_action(obs)
#      80 if self.obs_parser.is_open_door and action == 2 and not self.is_went_through_door:
#      81     print("Agent went through the door!")
#
# Cell In[83], line 29, in Agent.get_action(self, obs)
#      25 print(f"Querying LLM with state: {state_desc}")
#      27 # print(f"Prompt: {prompt}")
# ---> 29 response = self.llm.query(
#      30     prompt,
#      31     system_prompt=self.prompt_manager.system_prompt
#      32 )
#      34 print(f"Response: {response}")
#      36 # Parse action from response
#
# Cell In[84], line 44, in OpenAIInterface.query(self, prompt, system_prompt)
#      41     messages.append({"role": "system", "content": system_prompt})
#      42 messages.append({"role": "user", "content": prompt})
# ---> 44 response = self.client.chat.completions.create(
#      45     model=self.model,
#      46     messages=messages,
#      47     temperature=0.1,  # Low temperature for consistency
#      48     max_tokens=200
#      49 )
#      51 return response.choices[0].message.content
#
# File d:\Study\Personal\Projects\LLMaE-PPO\.venv\Lib\site-packages\openai\_utils\_utils.py:287, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     285             msg = f"Missing required argument: {quote(missing[0])}"
#     286     raise TypeError(msg)
# --> 287 return func(*args, **kwargs)
#
# File d:\Study\Personal\Projects\LLMaE-PPO\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:1131, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1086 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1087 def create(
#    1088     self,
#    (...)   1128     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#    1129 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1130     validate_response_format(response_format)
# -> 1131     return self._post(
#    1132         "/chat/completions",
#    1133         body=maybe_transform(
#    1134             {
#    1135                 "messages": messages,
#    1136                 "model": model,
#    1137                 "audio": audio,
#    1138                 "frequency_penalty": frequency_penalty,
#    1139                 "function_call": function_call,
#    1140                 "functions": functions,
#    1141                 "logit_bias": logit_bias,
#    1142                 "logprobs": logprobs,
#    1143                 "max_completion_tokens": max_completion_tokens,
#    1144                 "max_tokens": max_tokens,
#    1145                 "metadata": metadata,
#    1146                 "modalities": modalities,
#    1147                 "n": n,
#    1148                 "parallel_tool_calls": parallel_tool_calls,
#    1149                 "prediction": prediction,
#    1150                 "presence_penalty": presence_penalty,
#    1151                 "prompt_cache_key": prompt_cache_key,
#    1152                 "reasoning_effort": reasoning_effort,
#    1153                 "response_format": response_format,
#    1154                 "safety_identifier": safety_identifier,
#    1155                 "seed": seed,
#    1156                 "service_tier": service_tier,
#    1157                 "stop": stop,
#    1158                 "store": store,
#    1159                 "stream": stream,
#    1160                 "stream_options": stream_options,
#    1161                 "temperature": temperature,
#    1162                 "tool_choice": tool_choice,
#    1163                 "tools": tools,
#    1164                 "top_logprobs": top_logprobs,
#    1165                 "top_p": top_p,
#    1166                 "user": user,
#    1167                 "web_search_options": web_search_options,
#    1168             },
#    1169             completion_create_params.CompletionCreateParamsStreaming
#    1170             if stream
#    1171             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1172         ),
#    1173         options=make_request_options(
#    1174             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1175         ),
#    1176         cast_to=ChatCompletion,
#    1177         stream=stream or False,
#    1178         stream_cls=Stream[ChatCompletionChunk],
#    1179     )
#
# File d:\Study\Personal\Projects\LLMaE-PPO\.venv\Lib\site-packages\openai\_base_client.py:1256, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1242 def post(
#    1243     self,
#    1244     path: str,
#    (...)   1251     stream_cls: type[_StreamT] | None = None,
#    1252 ) -> ResponseT | _StreamT:
#    1253     opts = FinalRequestOptions.construct(
#    1254         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1255     )
# -> 1256     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File d:\Study\Personal\Projects\LLMaE-PPO\.venv\Lib\site-packages\openai\_base_client.py:979, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#     977 response = None
#     978 try:
# --> 979     response = self._client.send(
#     980         request,
#     981         stream=stream or self._should_stream_response_body(request=request),
#     982         **kwargs,
#     983     )
#     984 except httpx.TimeoutException as err:
#     985     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File d:\Study\Personal\Projects\LLMaE-PPO\.venv\Lib\site-packages\httpx\_client.py:928, in Client.send(self, request, stream, auth, follow_redirects)
#     926 except BaseException as exc:
#     927     response.close()
# --> 928     raise exc
#
# File d:\Study\Personal\Projects\LLMaE-PPO\.venv\Lib\site-packages\httpx\_client.py:922, in Client.send(self, request, stream, auth, follow_redirects)
#     920 try:
#     921     if not stream:
# --> 922         response.read()
#     924     return response
#     926 except BaseException as exc:
#
# File d:\Study\Personal\Projects\LLMaE-PPO\.venv\Lib\site-packages\httpx\_models.py:881, in Response.read(self)
#     877 """
#     878 Read and return the response content.
#     879 """
#     880 if not hasattr(self, "_content"):
# --> 881     self._content = b"".join(self.iter_bytes())
#     882 return self._content
#
# File d:\Study\Personal\Projects\LLMaE-PPO\.venv\Lib\site-packages\httpx\_models.py:897, in Response.iter_bytes(self, chunk_size)
#     895 chunker = ByteChunker(chunk_size=chunk_size)
#     896 with request_context(request=self._request):
# --> 897     for raw_bytes in self.iter_raw():
#     898         decoded = decoder.decode(raw_bytes)
#     899         for chunk in chunker.decode(decoded):
#
# File d:\Study\Personal\Projects\LLMaE-PPO\.venv\Lib\site-packages\httpx\_models.py:951, in Response.iter_raw(self, chunk_size)
#     948 chunker = ByteChunker(chunk_size=chunk_size)
#     950 with request_context(request=self._request):
# --> 951     for raw_stream_bytes in self.stream:
#     952         self._num_bytes_downloaded += len(raw_stream_bytes)
#     953         for chunk in chunker.decode(raw_stream_bytes):
#
# File d:\Study\Personal\Projects\LLMaE-PPO\.venv\Lib\site-packages\httpx\_client.py:153, in BoundSyncStream.__iter__(self)
#     152 def __iter__(self) -> typing.Iterator[bytes]:
# --> 153     for chunk in self._stream:
#     154         yield chunk
#
# File d:\Study\Personal\Projects\LLMaE-PPO\.venv\Lib\site-packages\httpx\_transports\default.py:127, in ResponseStream.__iter__(self)
#     125 def __iter__(self) -> typing.Iterator[bytes]:
#     126     with map_httpcore_exceptions():
# --> 127         for part in self._httpcore_stream:
#     128             yield part
#
# File d:\Study\Personal\Projects\LLMaE-PPO\.venv\Lib\site-packages\httpcore\_sync\connection_pool.py:407, in PoolByteStream.__iter__(self)
#     405 except BaseException as exc:
#     406     self.close()
# --> 407     raise exc from None
#
# File d:\Study\Personal\Projects\LLMaE-PPO\.venv\Lib\site-packages\httpcore\_sync\connection_pool.py:403, in PoolByteStream.__iter__(self)
#     401 def __iter__(self) -> typing.Iterator[bytes]:
#     402     try:
# --> 403         for part in self._stream:
#     404             yield part
#     405     except BaseException as exc:
#
# File d:\Study\Personal\Projects\LLMaE-PPO\.venv\Lib\site-packages\httpcore\_sync\http11.py:342, in HTTP11ConnectionByteStream.__iter__(self)
#     340 with ShieldCancellation():
#     341     self.close()
# --> 342 raise exc
#
# File d:\Study\Personal\Projects\LLMaE-PPO\.venv\Lib\site-packages\httpcore\_sync\http11.py:334, in HTTP11ConnectionByteStream.__iter__(self)
#     332 try:
#     333     with Trace("receive_response_body", logger, self._request, kwargs):
# --> 334         for chunk in self._connection._receive_response_body(**kwargs):
#     335             yield chunk
#     336 except BaseException as exc:
#     337     # If we get an exception while streaming the response,
#     338     # we want to close the response (and possibly the connection)
#     339     # before raising that exception.
#
# File d:\Study\Personal\Projects\LLMaE-PPO\.venv\Lib\site-packages\httpcore\_sync\http11.py:203, in HTTP11Connection._receive_response_body(self, request)
#     200 timeout = timeouts.get("read", None)
#     202 while True:
# --> 203     event = self._receive_event(timeout=timeout)
#     204     if isinstance(event, h11.Data):
#     205         yield bytes(event.data)
#
# File d:\Study\Personal\Projects\LLMaE-PPO\.venv\Lib\site-packages\httpcore\_sync\http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File d:\Study\Personal\Projects\LLMaE-PPO\.venv\Lib\site-packages\httpcore\_backends\sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File ~\AppData\Roaming\uv\python\cpython-3.11.13-windows-x86_64-none\Lib\ssl.py:1295, in SSLSocket.recv(self, buflen, flags)
#    1291     if flags != 0:
#    1292         raise ValueError(
#    1293             "non-zero flags not allowed in calls to recv() on %s" %
#    1294             self.__class__)
# -> 1295     return self.read(buflen)
#    1296 else:
#    1297     return super().recv(buflen, flags)
#
# File ~\AppData\Roaming\uv\python\cpython-3.11.13-windows-x86_64-none\Lib\ssl.py:1168, in SSLSocket.read(self, len, buffer)
#    1166         return self._sslobj.read(len, buffer)
#    1167     else:
# -> 1168         return self._sslobj.read(len)
#    1169 except SSLError as x:
#    1170     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
