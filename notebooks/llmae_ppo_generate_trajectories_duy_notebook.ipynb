# %%
import gymnasium as gym
import openai
import re
from minigrid.wrappers import FlatObsWrapper
from openai import OpenAI
import os
import pickle
import minigrid
import pprint
import json
import dotenv
import numpy as np
from dotenv import load_dotenv
from minigrid.core.world_object import Door, Key, Goal, Wall, Lava
# Out:
# d:\Study\Personal\Projects\LLMaE-PPO\.venv\Lib\site-packages\pygame\pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists

# %%
def describe_environment(env):
    grid = env.unwrapped.grid
    width, height = grid.width, grid.height
    description = [f"Environment: {env.spec.id}, {width}x{height} grid"]

    # Get all directions
    directions = ['right', 'down', 'left', 'up']
    for i, direction in enumerate(directions):
        description.append(f"Direction {i}: {direction}")

    for action in range(env.action_space.n):
        description.append(f"Action {action}: {env.unwrapped.actions(action).name}")

    # Store object positions as tuples
    object_positions = []
    wall_positions = []
    
    for x in range(width):
        for y in range(height):
            obj = grid.get(x, y)
            if obj is not None:
                obj_desc = ''
                if isinstance(obj, Wall):
                    wall_desc = f"{x, y}"
                    wall_positions.append(wall_desc)
                elif isinstance(obj, Door):
                    obj_desc += f"Door at {x, y}, is locked: True"
                    object_positions.append(obj_desc)
                    door_pos = [x, y]
                elif isinstance(obj, Key):
                    obj_desc += f"Key at {x, y}"
                    object_positions.append(obj_desc)
                    key_pos = [x, y]
                elif isinstance(obj, Goal):
                    obj_desc += f"Goal at {x, y}"
                    object_positions.append(obj_desc)
                    goal_pos = [x, y]
    agent_pos = list(int(x) for x in env.unwrapped.agent_pos)
    agent_dir = int(env.unwrapped.agent_dir)
    description.append(f"Agent starts at {tuple(agent_pos)}; facing direction {agent_dir}")
    description.append(f"Mission: {env.unwrapped.mission}")
    description.append(f"Object positions: {object_positions}")
    description.append(f"Wall positions: {wall_positions}")
    
    return "\n".join(description), agent_pos, door_pos, key_pos, goal_pos

# Example usage
seed = 9
env = gym.make("MiniGrid-DoorKey-8x8-v0")
# env = gym.make("MiniGrid-DoorKey-8x8-v0", render_mode="rgb_array")
env = FlatObsWrapper(env)  # Flatten the observation space
env = gym.wrappers.RecordEpisodeStatistics(env)
# env = gym.wrappers.RecordVideo(env, "videos/test")
# env.reset(seed=seed)
#test_env, agent_pos, door_pos, key_pos, goal_pos = describe_environment(env)
#
#print(agent_pos, door_pos, key_pos, goal_pos)

# %%
def get_trajectory_from_llm(env_description):
    """
    Get a trajectory from LLM for solving the environment
    
    Args:
        env_description (str): Description of the environment
        model (str): Model to use for generation
        temperature (float, optional): Temperature for generation
    
    Returns:
        str: Generated trajectory response
    """
    # Load environment variables
    load_dotenv()

    # Initialize OpenAI client
    client = OpenAI(
        api_key=os.getenv('OPENAI_API_KEY'),
        base_url=os.getenv('OPENAI_BASE_URL')
    )

    # Define prompts
    system_prompt = 'You are a helpful AI assistant who is expert at ReinforcementLearning'
    user_prompt = f'''I have this environment: {env_description}. 
    Please generate ONLY ONE trajectory to solve this environment in this exact format:
    {{"action": <action_number>}}
    Where action_number is an integer.
    I need ONLY the trajectory in that format. Do not ADD any other words.'''

    try:
        # Create chat completion
        completion = client.chat.completions.create(
            model="deepseek/deepseek-chat-v3-0324:free",
            messages=[
                {"role": "system", "content": system_prompt},
                {"role": "user", "content": user_prompt}
            ]
        )
        
        response = completion.choices[0].message.content
        return response

    except Exception as e:
        print(f"Error with OpenAI API: {e}")
        return None


response = get_trajectory_from_llm(test_env)
print(response)
# Out:
# {"action": 2}
# {"action": 3}
# {"action": 2}
# {"action": 2}
# {"action": 1}
# {"action": 1}
# {"action": 1}
# {"action": 0}
# {"action": 2}
# {"action": 5}
# {"action": 2}
# {"action": 0}
# {"action": 2}
# {"action": 2}
# {"action": 1}
# {"action": 1}
# {"action": 2}

# %%
def parse_json(response):
    """
    Parse JSON response from LLM into list of trajectory dictionaries
    
    Args:
        response (str): JSON response string from LLM
        
    Returns:
        list: List of trajectory dictionaries with action/observation pairs
    """

    # Handle empty or None response
    if not response:
        return []
    
    # Strip code block markers if they exist
    response = response.strip()
    if response.startswith('```'):
        # Remove first line containing ```json or similar
        response = '\n'.join(response.split('\n')[1:])
    if response.endswith('```'):
        # Remove last line containing ```
        response = '\n'.join(response.split('\n')[:-1])
    if response.startswith('['):
        # Remove first line containing [ or similar
        response = '\n'.join(response.split('\n')[1:])
    if response.endswith(']'):
        # Remove last line containing ]
        response = '\n'.join(response.split('\n')[:-1])

    # Extract just the JSON part from the response
    # Convert lines into list of dictionaries
    trajectories = []
    for line in response.split('\n'):
        line = line.strip()
        if line.startswith('{') and line.endswith('}'):
            try:
                trajectory = json.loads(line)
                trajectories.append(trajectory)
            except json.JSONDecodeError as e:
                print(f"Error parsing line: {e}")
                continue

    return trajectories


trajectories = parse_json(response)

print(trajectories)

# Create a dictionary with metadata and trajectories
data_to_save = {
    "seed": seed,
    "trajectories": trajectories
}

# Save to JSON file with proper formatting
output_path = "trajectories.json"
with open(output_path, 'w', encoding='utf-8') as f:
    json.dump(data_to_save, f, indent=2, ensure_ascii=False)

print(f"Saved trajectories to {output_path}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 47
#      42                 continue
#      44     return trajectories
# ---> 47 trajectories = parse_json(response)
#      49 print(trajectories)
#      51 # Create a dictionary with metadata and trajectories
#
# NameError: name 'response' is not defined

# %%
def load_trajectory_from_json(json_file):
    """Load trajectory data for a specific seed from JSON file"""
    with open(json_file, 'r') as f:
        data = json.load(f)
    trajectories = data['trajectories']
    seed = data['seed']
    return seed, trajectories

# Example usage
seed, trajectories = load_trajectory_from_json('expert_data_multiple_seeds/trajectory_seed_0.json')

print(seed)
print(trajectories)
# Out:
# 0
# [{'action': 2}, {'action': 0}, {'action': 3}, {'action': 2}, {'action': 0}, {'action': 2}, {'action': 2}, {'action': 2}, {'action': 1}, {'action': 5}, {'action': 2}, {'action': 2}, {'action': 1}, {'action': 2}, {'action': 2}, {'action': 2}, {'action': 2}]

# %%
def simulate_environment(env, seed, trajectory):
    """
    Simulate environment with given trajectory and collect state-action pairs
    
    Args:
        env: Gymnasium environment
        seed (int): Seed for environment reproducibility
        trajectory (list): List of trajectory dictionaries with actions

    Returns:
        list: List of state-action pair dictionaries
    """
    # Reset environment with seed to get initial state
    obs, _ = env.reset(seed=seed)

    # State-action pair storage
    state_action_pairs = []

    # Extract actions from trajectory data
    actions = [t['action'] for t in trajectory]

    # Store state-action pairs correctly
    for action in actions:
        # Store current state with action to be taken from this state
        pair = {
            'state': obs.copy(),  # Current state
            'action': action      # Action to take from this state
        }
        state_action_pairs.append(pair)

        # Execute action and get next state
        obs, reward, terminated, truncated, _ = env.step(action)

        if terminated or truncated:
            break

    return state_action_pairs
# Example usage

state_action_pairs = simulate_environment(env, seed, trajectories)
print(state_action_pairs)
# Out:
# [{'state': array([0, 0, 0, ..., 0, 0, 0], shape=(2835,), dtype=uint8), 'action': 2}, {'state': array([0, 0, 0, ..., 0, 0, 0], shape=(2835,), dtype=uint8), 'action': 0}, {'state': array([0, 0, 0, ..., 0, 0, 0], shape=(2835,), dtype=uint8), 'action': 3}, {'state': array([0, 0, 0, ..., 0, 0, 0], shape=(2835,), dtype=uint8), 'action': 2}, {'state': array([0, 0, 0, ..., 0, 0, 0], shape=(2835,), dtype=uint8), 'action': 0}, {'state': array([0, 0, 0, ..., 0, 0, 0], shape=(2835,), dtype=uint8), 'action': 2}, {'state': array([0, 0, 0, ..., 0, 0, 0], shape=(2835,), dtype=uint8), 'action': 2}, {'state': array([0, 0, 0, ..., 0, 0, 0], shape=(2835,), dtype=uint8), 'action': 2}, {'state': array([0, 0, 0, ..., 0, 0, 0], shape=(2835,), dtype=uint8), 'action': 1}, {'state': array([0, 0, 0, ..., 0, 0, 0], shape=(2835,), dtype=uint8), 'action': 5}, {'state': array([0, 0, 0, ..., 0, 0, 0], shape=(2835,), dtype=uint8), 'action': 2}, {'state': array([0, 0, 0, ..., 0, 0, 0], shape=(2835,), dtype=uint8), 'action': 2}, {'state': array([0, 0, 0, ..., 0, 0, 0], shape=(2835,), dtype=uint8), 'action': 1}, {'state': array([0, 0, 0, ..., 0, 0, 0], shape=(2835,), dtype=uint8), 'action': 2}, {'state': array([0, 0, 0, ..., 0, 0, 0], shape=(2835,), dtype=uint8), 'action': 2}, {'state': array([0, 0, 0, ..., 0, 0, 0], shape=(2835,), dtype=uint8), 'action': 2}, {'state': array([0, 0, 0, ..., 0, 0, 0], shape=(2835,), dtype=uint8), 'action': 2}]

# %%
def save_trajectory_pkl(seed, state_action_pairs, trajectory_index):
    # Create trajectory_data_2 directory if it doesn't exist
    os.makedirs('trajectory_data_4', exist_ok=True)

    # Generate filename with trajectory index and seed (matching expert_data_2 format)
    output_path = os.path.join('trajectory_data_4', f'trajectory_seed_{seed}.pkl')

    # Save to pickle file
    with open(output_path, 'wb') as f:
        pickle.dump(state_action_pairs, f)
    
    print(f"Saved trajectories to {output_path}")

# Usage example:
# save_trajectory_pkl(seed, state_action_pairs, trajectory_index=0)

# # To load the data later:
# def load_trajectory(seed):
#     """Load trajectory data for a specific seed"""
#     filepath = os.path.join('trajectory_data_2', f'trajectories_seed{seed}.pkl')
#     with open(filepath, 'rb') as f:
#         data = pickle.load(f)
#     return data

# check = load_trajectory(seed=seed)

# print(check)

# %%
def validate_trajectory(env, trajectory_data, goal_position, seed):
    """
    Validates if a sequence of actions reaches the goal position.
    
    Args:
        env: Gymnasium environment
        actions: List of actions to execute
        goal_position: Target position to reach [x, y]
        seed: Random seed for environment (optional)
    
    Returns:
        bool: True if trajectory reaches goal, False otherwise
    """

    # Extract actions from trajecotry data
    actions = [t['action'] for t in trajectory_data]

    # Execute actions and track progress
    for step_idx, action in enumerate(actions):
        next_obs, reward, terminated, truncated, next_info = env.step(action)
        agent_pos = list(int(x) for x in env.unwrapped.agent_pos)
        agent_dir = env.unwrapped.agent_dir
        print(f"Step {step_idx + 1}: Action {action}: {env.unwrapped.actions(action).name}")
        print(f"Position: {agent_pos}, Direction: {agent_dir}")
        
        # Check if reached goal successfully
        if terminated and reward > 0 and agent_pos == goal_position:
            return True
            
        # Check if trajectory failed
        if truncated:
            return False
    
    # If exit the loop without reaching the goal
    return False

#Load trajectories from JSON file
with open('trajectories.json', 'r') as f:
    data = json.load(f)
    trajectory_data = data['trajectories']

print(trajectory_data)

#Reset environment with seed if provided
env.reset(seed=seed)
success = validate_trajectory(env, trajectory_data, goal_pos, seed=1)
print(f"Trajectory {'succeeded' if success else 'failed'} to reach goal")
# Out:
# [{'action': 2, 'observation': 'Agent moves forward to (1, 5), facing up'}, {'action': 1, 'observation': 'Agent turns right, now facing right'}, {'action': 2, 'observation': 'Agent moves forward to (2, 5), facing right'}, {'action': 2, 'observation': 'Agent moves forward to (3, 5), facing right'}, {'action': 0, 'observation': 'Agent turns left, now facing up'}, {'action': 2, 'observation': 'Agent moves forward to (3, 4), facing up'}, {'action': 2, 'observation': 'Agent moves forward to (3, 3), facing up'}, {'action': 2, 'observation': 'Agent moves forward to (3, 2), facing up, cannot move further'}, {'action': 1, 'observation': 'Agent turns right, now facing right'}, {'action': 2, 'observation': 'Agent moves forward to (4, 2), facing right'}, {'action': 0, 'observation': 'Agent turns left, now facing up'}, {'action': 2, 'observation': 'Agent moves forward to (4, 1), facing up'}, {'action': 3, 'observation': 'Agent picks up the key at (4, 1)'}, {'action': 1, 'observation': 'Agent turns right, now facing right'}, {'action': 2, 'observation': 'Agent moves forward to (5, 1), facing right'}, {'action': 0, 'observation': 'Agent turns left, now facing up'}, {'action': 2, 'observation': 'Agent moves forward to (5, 0), facing up, cannot move further'}, {'action': 1, 'observation': 'Agent turns right, now facing right'}, {'action': 2, 'observation': 'Agent moves forward to (6, 0), facing right, cannot move further'}, {'action': 0, 'observation': 'Agent turns left, now facing up'}, {'action': 2, 'observation': 'Agent moves forward to (6, 1), facing up, cannot move further'}, {'action': 0, 'observation': 'Agent turns left, now facing left'}, {'action': 2, 'observation': 'Agent moves forward to (5, 1), facing left'}, {'action': 0, 'observation': 'Agent turns left, now facing down'}, {'action': 2, 'observation': 'Agent moves forward to (5, 2), facing down'}, {'action': 1, 'observation': 'Agent turns right, now facing left'}, {'action': 2, 'observation': 'Agent moves forward to (4, 2), facing left'}, {'action': 1, 'observation': 'Agent turns right, now facing down'}, {'action': 2, 'observation': 'Agent moves forward to (4, 3), facing down'}, {'action': 2, 'observation': 'Agent moves forward to (4, 4), facing down'}, {'action': 2, 'observation': 'Agent moves forward to (4, 5), facing down'}, {'action': 2, 'observation': 'Agent moves forward to (4, 6), facing down'}, {'action': 0, 'observation': 'Agent turns left, now facing right'}, {'action': 2, 'observation': 'Agent moves forward to (5, 6), facing right'}, {'action': 2, 'observation': 'Agent moves forward to (6, 6), facing right, reaches the goal'}, {'action': 6, 'observation': 'Mission completed'}]

# %%
def simulate_and_save_trajectory(env, data_dir):
    for file in os.listdir(data_dir):
        if file.endswith(".json"):
            seed, trajectory = load_trajectory_from_json(os.path.join(data_dir, file))
            # trajectory_index = int(file.split('_')[1])
            state_action_pairs = simulate_environment(env, seed, trajectory)
            save_trajectory_pkl(seed, state_action_pairs, 0)
            print(f"Generated and saved state-actions pairs for seed {seed}")

simulate_and_save_trajectory(env, "expert_data_multiple_seeds")
# Out:
# Saved trajectories to trajectory_data_4\trajectory_0_seed_0.pkl
# Generated and saved state-actions pairs for seed 0
# Saved trajectories to trajectory_data_4\trajectory_0_seed_10.pkl
# Generated and saved state-actions pairs for seed 10
# Saved trajectories to trajectory_data_4\trajectory_0_seed_1000.pkl
# Generated and saved state-actions pairs for seed 1000
# Saved trajectories to trajectory_data_4\trajectory_0_seed_103.pkl
# Generated and saved state-actions pairs for seed 103
# Saved trajectories to trajectory_data_4\trajectory_0_seed_107.pkl
# Generated and saved state-actions pairs for seed 107
# Saved trajectories to trajectory_data_4\trajectory_0_seed_110.pkl
# Generated and saved state-actions pairs for seed 110
# Saved trajectories to trajectory_data_4\trajectory_0_seed_116.pkl
# Generated and saved state-actions pairs for seed 116
# Saved trajectories to trajectory_data_4\trajectory_0_seed_12.pkl
# Generated and saved state-actions pairs for seed 12
# Saved trajectories to trajectory_data_4\trajectory_0_seed_127.pkl
# Generated and saved state-actions pairs for seed 127
# Saved trajectories to trajectory_data_4\trajectory_0_seed_136.pkl
# Generated and saved state-actions pairs for seed 136
# Saved trajectories to trajectory_data_4\trajectory_0_seed_14.pkl
# Generated and saved state-actions pairs for seed 14
# Saved trajectories to trajectory_data_4\trajectory_0_seed_140.pkl
# Generated and saved state-actions pairs for seed 140
# Saved trajectories to trajectory_data_4\trajectory_0_seed_141.pkl
# Generated and saved state-actions pairs for seed 141
# Saved trajectories to trajectory_data_4\trajectory_0_seed_142.pkl
# Generated and saved state-actions pairs for seed 142
# Saved trajectories to trajectory_data_4\trajectory_0_seed_144.pkl
# Generated and saved state-actions pairs for seed 144
# Saved trajectories to trajectory_data_4\trajectory_0_seed_149.pkl
# Generated and saved state-actions pairs for seed 149
# Saved trajectories to trajectory_data_4\trajectory_0_seed_15.pkl
# Generated and saved state-actions pairs for seed 15
# Saved trajectories to trajectory_data_4\trajectory_0_seed_153.pkl
# Generated and saved state-actions pairs for seed 153
# Saved trajectories to trajectory_data_4\trajectory_0_seed_154.pkl
# Generated and saved state-actions pairs for seed 154
# Saved trajectories to trajectory_data_4\trajectory_0_seed_157.pkl
# Generated and saved state-actions pairs for seed 157
# Saved trajectories to trajectory_data_4\trajectory_0_seed_164.pkl
# Generated and saved state-actions pairs for seed 164
# Saved trajectories to trajectory_data_4\trajectory_0_seed_173.pkl
# Generated and saved state-actions pairs for seed 173
# Saved trajectories to trajectory_data_4\trajectory_0_seed_175.pkl
# Generated and saved state-actions pairs for seed 175
# Saved trajectories to trajectory_data_4\trajectory_0_seed_186.pkl
# Generated and saved state-actions pairs for seed 186
# Saved trajectories to trajectory_data_4\trajectory_0_seed_189.pkl
# Generated and saved state-actions pairs for seed 189
# Saved trajectories to trajectory_data_4\trajectory_0_seed_191.pkl
# Generated and saved state-actions pairs for seed 191
# Saved trajectories to trajectory_data_4\trajectory_0_seed_195.pkl
# Generated and saved state-actions pairs for seed 195
# Saved trajectories to trajectory_data_4\trajectory_0_seed_201.pkl
# Generated and saved state-actions pairs for seed 201
# Saved trajectories to trajectory_data_4\trajectory_0_seed_202.pkl
# Generated and saved state-actions pairs for seed 202
# Saved trajectories to trajectory_data_4\trajectory_0_seed_207.pkl
# Generated and saved state-actions pairs for seed 207
# Saved trajectories to trajectory_data_4\trajectory_0_seed_209.pkl
# Generated and saved state-actions pairs for seed 209
# Saved trajectories to trajectory_data_4\trajectory_0_seed_21.pkl
# Generated and saved state-actions pairs for seed 21
# Saved trajectories to trajectory_data_4\trajectory_0_seed_213.pkl
# Generated and saved state-actions pairs for seed 213
# Saved trajectories to trajectory_data_4\trajectory_0_seed_217.pkl
# Generated and saved state-actions pairs for seed 217
# Saved trajectories to trajectory_data_4\trajectory_0_seed_22.pkl
# Generated and saved state-actions pairs for seed 22
# Saved trajectories to trajectory_data_4\trajectory_0_seed_229.pkl
# Generated and saved state-actions pairs for seed 229
# Saved trajectories to trajectory_data_4\trajectory_0_seed_233.pkl
# Generated and saved state-actions pairs for seed 233
# Saved trajectories to trajectory_data_4\trajectory_0_seed_240.pkl
# Generated and saved state-actions pairs for seed 240
# Saved trajectories to trajectory_data_4\trajectory_0_seed_25.pkl
# Generated and saved state-actions pairs for seed 25
# Saved trajectories to trajectory_data_4\trajectory_0_seed_252.pkl
# Generated and saved state-actions pairs for seed 252
# Saved trajectories to trajectory_data_4\trajectory_0_seed_253.pkl
# Generated and saved state-actions pairs for seed 253
# Saved trajectories to trajectory_data_4\trajectory_0_seed_256.pkl
# Generated and saved state-actions pairs for seed 256
# Saved trajectories to trajectory_data_4\trajectory_0_seed_257.pkl
# Generated and saved state-actions pairs for seed 257
# Saved trajectories to trajectory_data_4\trajectory_0_seed_260.pkl
# Generated and saved state-actions pairs for seed 260
# Saved trajectories to trajectory_data_4\trajectory_0_seed_261.pkl
# Generated and saved state-actions pairs for seed 261
# Saved trajectories to trajectory_data_4\trajectory_0_seed_265.pkl
# Generated and saved state-actions pairs for seed 265
# Saved trajectories to trajectory_data_4\trajectory_0_seed_269.pkl
# Generated and saved state-actions pairs for seed 269
# Saved trajectories to trajectory_data_4\trajectory_0_seed_272.pkl
# Generated and saved state-actions pairs for seed 272
# Saved trajectories to trajectory_data_4\trajectory_0_seed_282.pkl
# Generated and saved state-actions pairs for seed 282
# Saved trajectories to trajectory_data_4\trajectory_0_seed_298.pkl
# Generated and saved state-actions pairs for seed 298
# Saved trajectories to trajectory_data_4\trajectory_0_seed_302.pkl
# Generated and saved state-actions pairs for seed 302
# Saved trajectories to trajectory_data_4\trajectory_0_seed_305.pkl
# Generated and saved state-actions pairs for seed 305
# Saved trajectories to trajectory_data_4\trajectory_0_seed_310.pkl
# Generated and saved state-actions pairs for seed 310
# Saved trajectories to trajectory_data_4\trajectory_0_seed_319.pkl
# Generated and saved state-actions pairs for seed 319
# Saved trajectories to trajectory_data_4\trajectory_0_seed_329.pkl
# Generated and saved state-actions pairs for seed 329
# Saved trajectories to trajectory_data_4\trajectory_0_seed_330.pkl
# Generated and saved state-actions pairs for seed 330
# Saved trajectories to trajectory_data_4\trajectory_0_seed_338.pkl
# Generated and saved state-actions pairs for seed 338
# Saved trajectories to trajectory_data_4\trajectory_0_seed_348.pkl
# Generated and saved state-actions pairs for seed 348
# Saved trajectories to trajectory_data_4\trajectory_0_seed_349.pkl
# Generated and saved state-actions pairs for seed 349
# Saved trajectories to trajectory_data_4\trajectory_0_seed_360.pkl
# Generated and saved state-actions pairs for seed 360
# Saved trajectories to trajectory_data_4\trajectory_0_seed_367.pkl
# Generated and saved state-actions pairs for seed 367
# Saved trajectories to trajectory_data_4\trajectory_0_seed_369.pkl
# Generated and saved state-actions pairs for seed 369
# Saved trajectories to trajectory_data_4\trajectory_0_seed_374.pkl
# Generated and saved state-actions pairs for seed 374
# Saved trajectories to trajectory_data_4\trajectory_0_seed_379.pkl
# Generated and saved state-actions pairs for seed 379
# Saved trajectories to trajectory_data_4\trajectory_0_seed_381.pkl
# Generated and saved state-actions pairs for seed 381
# Saved trajectories to trajectory_data_4\trajectory_0_seed_382.pkl
# Generated and saved state-actions pairs for seed 382
# Saved trajectories to trajectory_data_4\trajectory_0_seed_383.pkl
# Generated and saved state-actions pairs for seed 383
# Saved trajectories to trajectory_data_4\trajectory_0_seed_387.pkl
# Generated and saved state-actions pairs for seed 387
# Saved trajectories to trajectory_data_4\trajectory_0_seed_390.pkl
# Generated and saved state-actions pairs for seed 390
# Saved trajectories to trajectory_data_4\trajectory_0_seed_4.pkl
# Generated and saved state-actions pairs for seed 4
# Saved trajectories to trajectory_data_4\trajectory_0_seed_40.pkl
# Generated and saved state-actions pairs for seed 40
# Saved trajectories to trajectory_data_4\trajectory_0_seed_402.pkl
# Generated and saved state-actions pairs for seed 402
# Saved trajectories to trajectory_data_4\trajectory_0_seed_403.pkl
# Generated and saved state-actions pairs for seed 403
# Saved trajectories to trajectory_data_4\trajectory_0_seed_404.pkl
# Generated and saved state-actions pairs for seed 404
# Saved trajectories to trajectory_data_4\trajectory_0_seed_405.pkl
# Generated and saved state-actions pairs for seed 405
# Saved trajectories to trajectory_data_4\trajectory_0_seed_407.pkl
# Generated and saved state-actions pairs for seed 407
# Saved trajectories to trajectory_data_4\trajectory_0_seed_412.pkl
# Generated and saved state-actions pairs for seed 412
# Saved trajectories to trajectory_data_4\trajectory_0_seed_414.pkl
# Generated and saved state-actions pairs for seed 414
# Saved trajectories to trajectory_data_4\trajectory_0_seed_42.pkl
# Generated and saved state-actions pairs for seed 42
# Saved trajectories to trajectory_data_4\trajectory_0_seed_420.pkl
# Generated and saved state-actions pairs for seed 420
# Saved trajectories to trajectory_data_4\trajectory_0_seed_425.pkl
# Generated and saved state-actions pairs for seed 425
# Saved trajectories to trajectory_data_4\trajectory_0_seed_43.pkl
# Generated and saved state-actions pairs for seed 43
# Saved trajectories to trajectory_data_4\trajectory_0_seed_431.pkl
# Generated and saved state-actions pairs for seed 431
# Saved trajectories to trajectory_data_4\trajectory_0_seed_436.pkl
# Generated and saved state-actions pairs for seed 436
# Saved trajectories to trajectory_data_4\trajectory_0_seed_442.pkl
# Generated and saved state-actions pairs for seed 442
# Saved trajectories to trajectory_data_4\trajectory_0_seed_445.pkl
# Generated and saved state-actions pairs for seed 445
# Saved trajectories to trajectory_data_4\trajectory_0_seed_447.pkl
# Generated and saved state-actions pairs for seed 447
# Saved trajectories to trajectory_data_4\trajectory_0_seed_449.pkl
# Generated and saved state-actions pairs for seed 449
# Saved trajectories to trajectory_data_4\trajectory_0_seed_452.pkl
# Generated and saved state-actions pairs for seed 452
# Saved trajectories to trajectory_data_4\trajectory_0_seed_460.pkl
# Generated and saved state-actions pairs for seed 460
# Saved trajectories to trajectory_data_4\trajectory_0_seed_464.pkl
# Generated and saved state-actions pairs for seed 464
# Saved trajectories to trajectory_data_4\trajectory_0_seed_480.pkl
# Generated and saved state-actions pairs for seed 480
# Saved trajectories to trajectory_data_4\trajectory_0_seed_485.pkl
# Generated and saved state-actions pairs for seed 485
# Saved trajectories to trajectory_data_4\trajectory_0_seed_49.pkl
# Generated and saved state-actions pairs for seed 49
# Saved trajectories to trajectory_data_4\trajectory_0_seed_493.pkl
# Generated and saved state-actions pairs for seed 493
# Saved trajectories to trajectory_data_4\trajectory_0_seed_498.pkl
# Generated and saved state-actions pairs for seed 498
# Saved trajectories to trajectory_data_4\trajectory_0_seed_505.pkl
# Generated and saved state-actions pairs for seed 505
# Saved trajectories to trajectory_data_4\trajectory_0_seed_506.pkl
# Generated and saved state-actions pairs for seed 506
# Saved trajectories to trajectory_data_4\trajectory_0_seed_508.pkl
# Generated and saved state-actions pairs for seed 508
# Saved trajectories to trajectory_data_4\trajectory_0_seed_513.pkl
# Generated and saved state-actions pairs for seed 513
# Saved trajectories to trajectory_data_4\trajectory_0_seed_514.pkl
# Generated and saved state-actions pairs for seed 514
# Saved trajectories to trajectory_data_4\trajectory_0_seed_531.pkl
# Generated and saved state-actions pairs for seed 531
# Saved trajectories to trajectory_data_4\trajectory_0_seed_534.pkl
# Generated and saved state-actions pairs for seed 534
# Saved trajectories to trajectory_data_4\trajectory_0_seed_547.pkl
# Generated and saved state-actions pairs for seed 547
# Saved trajectories to trajectory_data_4\trajectory_0_seed_549.pkl
# Generated and saved state-actions pairs for seed 549
# Saved trajectories to trajectory_data_4\trajectory_0_seed_550.pkl
# Generated and saved state-actions pairs for seed 550
# Saved trajectories to trajectory_data_4\trajectory_0_seed_554.pkl
# Generated and saved state-actions pairs for seed 554
# Saved trajectories to trajectory_data_4\trajectory_0_seed_555.pkl
# Generated and saved state-actions pairs for seed 555
# Saved trajectories to trajectory_data_4\trajectory_0_seed_559.pkl
# Generated and saved state-actions pairs for seed 559
# Saved trajectories to trajectory_data_4\trajectory_0_seed_561.pkl
# Generated and saved state-actions pairs for seed 561
# Saved trajectories to trajectory_data_4\trajectory_0_seed_566.pkl
# Generated and saved state-actions pairs for seed 566
# Saved trajectories to trajectory_data_4\trajectory_0_seed_579.pkl
# Generated and saved state-actions pairs for seed 579
# Saved trajectories to trajectory_data_4\trajectory_0_seed_592.pkl
# Generated and saved state-actions pairs for seed 592
# Saved trajectories to trajectory_data_4\trajectory_0_seed_593.pkl
# Generated and saved state-actions pairs for seed 593
# Saved trajectories to trajectory_data_4\trajectory_0_seed_60.pkl
# Generated and saved state-actions pairs for seed 60
# Saved trajectories to trajectory_data_4\trajectory_0_seed_600.pkl
# Generated and saved state-actions pairs for seed 600
# Saved trajectories to trajectory_data_4\trajectory_0_seed_602.pkl
# Generated and saved state-actions pairs for seed 602
# Saved trajectories to trajectory_data_4\trajectory_0_seed_603.pkl
# Generated and saved state-actions pairs for seed 603
# Saved trajectories to trajectory_data_4\trajectory_0_seed_615.pkl
# Generated and saved state-actions pairs for seed 615
# Saved trajectories to trajectory_data_4\trajectory_0_seed_624.pkl
# Generated and saved state-actions pairs for seed 624
# Saved trajectories to trajectory_data_4\trajectory_0_seed_633.pkl
# Generated and saved state-actions pairs for seed 633
# Saved trajectories to trajectory_data_4\trajectory_0_seed_64.pkl
# Generated and saved state-actions pairs for seed 64
# Saved trajectories to trajectory_data_4\trajectory_0_seed_653.pkl
# Generated and saved state-actions pairs for seed 653
# Saved trajectories to trajectory_data_4\trajectory_0_seed_666.pkl
# Generated and saved state-actions pairs for seed 666
# Saved trajectories to trajectory_data_4\trajectory_0_seed_682.pkl
# Generated and saved state-actions pairs for seed 682
# Saved trajectories to trajectory_data_4\trajectory_0_seed_683.pkl
# Generated and saved state-actions pairs for seed 683
# Saved trajectories to trajectory_data_4\trajectory_0_seed_684.pkl
# Generated and saved state-actions pairs for seed 684
# Saved trajectories to trajectory_data_4\trajectory_0_seed_687.pkl
# Generated and saved state-actions pairs for seed 687
# Saved trajectories to trajectory_data_4\trajectory_0_seed_69.pkl
# Generated and saved state-actions pairs for seed 69
# Saved trajectories to trajectory_data_4\trajectory_0_seed_691.pkl
# Generated and saved state-actions pairs for seed 691
# Saved trajectories to trajectory_data_4\trajectory_0_seed_7.pkl
# Generated and saved state-actions pairs for seed 7
# Saved trajectories to trajectory_data_4\trajectory_0_seed_702.pkl
# Generated and saved state-actions pairs for seed 702
# Saved trajectories to trajectory_data_4\trajectory_0_seed_711.pkl
# Generated and saved state-actions pairs for seed 711
# Saved trajectories to trajectory_data_4\trajectory_0_seed_717.pkl
# Generated and saved state-actions pairs for seed 717
# Saved trajectories to trajectory_data_4\trajectory_0_seed_73.pkl
# Generated and saved state-actions pairs for seed 73
# Saved trajectories to trajectory_data_4\trajectory_0_seed_731.pkl
# Generated and saved state-actions pairs for seed 731
# Saved trajectories to trajectory_data_4\trajectory_0_seed_74.pkl
# Generated and saved state-actions pairs for seed 74
# Saved trajectories to trajectory_data_4\trajectory_0_seed_744.pkl
# Generated and saved state-actions pairs for seed 744
# Saved trajectories to trajectory_data_4\trajectory_0_seed_748.pkl
# Generated and saved state-actions pairs for seed 748
# Saved trajectories to trajectory_data_4\trajectory_0_seed_759.pkl
# Generated and saved state-actions pairs for seed 759
# Saved trajectories to trajectory_data_4\trajectory_0_seed_762.pkl
# Generated and saved state-actions pairs for seed 762
# Saved trajectories to trajectory_data_4\trajectory_0_seed_771.pkl
# Generated and saved state-actions pairs for seed 771
# Saved trajectories to trajectory_data_4\trajectory_0_seed_785.pkl
# Generated and saved state-actions pairs for seed 785
# Saved trajectories to trajectory_data_4\trajectory_0_seed_787.pkl
# Generated and saved state-actions pairs for seed 787
# Saved trajectories to trajectory_data_4\trajectory_0_seed_788.pkl
# Generated and saved state-actions pairs for seed 788
# Saved trajectories to trajectory_data_4\trajectory_0_seed_790.pkl
# Generated and saved state-actions pairs for seed 790
# Saved trajectories to trajectory_data_4\trajectory_0_seed_813.pkl
# Generated and saved state-actions pairs for seed 813
# Saved trajectories to trajectory_data_4\trajectory_0_seed_815.pkl
# Generated and saved state-actions pairs for seed 815
# Saved trajectories to trajectory_data_4\trajectory_0_seed_820.pkl
# Generated and saved state-actions pairs for seed 820
# Saved trajectories to trajectory_data_4\trajectory_0_seed_83.pkl
# Generated and saved state-actions pairs for seed 83
# Saved trajectories to trajectory_data_4\trajectory_0_seed_830.pkl
# Generated and saved state-actions pairs for seed 830
# Saved trajectories to trajectory_data_4\trajectory_0_seed_844.pkl
# Generated and saved state-actions pairs for seed 844
# Saved trajectories to trajectory_data_4\trajectory_0_seed_858.pkl
# Generated and saved state-actions pairs for seed 858
# Saved trajectories to trajectory_data_4\trajectory_0_seed_874.pkl
# Generated and saved state-actions pairs for seed 874
# Saved trajectories to trajectory_data_4\trajectory_0_seed_882.pkl
# Generated and saved state-actions pairs for seed 882
# Saved trajectories to trajectory_data_4\trajectory_0_seed_888.pkl
# Generated and saved state-actions pairs for seed 888
# Saved trajectories to trajectory_data_4\trajectory_0_seed_894.pkl
# Generated and saved state-actions pairs for seed 894
# Saved trajectories to trajectory_data_4\trajectory_0_seed_90.pkl
# Generated and saved state-actions pairs for seed 90
# Saved trajectories to trajectory_data_4\trajectory_0_seed_900.pkl
# Generated and saved state-actions pairs for seed 900
# Saved trajectories to trajectory_data_4\trajectory_0_seed_9001.pkl
# Generated and saved state-actions pairs for seed 9001
# Saved trajectories to trajectory_data_4\trajectory_0_seed_906.pkl
# Generated and saved state-actions pairs for seed 906
# Saved trajectories to trajectory_data_4\trajectory_0_seed_91.pkl
# Generated and saved state-actions pairs for seed 91
# Saved trajectories to trajectory_data_4\trajectory_0_seed_919.pkl
# Generated and saved state-actions pairs for seed 919
# Saved trajectories to trajectory_data_4\trajectory_0_seed_92.pkl
# Generated and saved state-actions pairs for seed 92
# Saved trajectories to trajectory_data_4\trajectory_0_seed_922.pkl
# Generated and saved state-actions pairs for seed 922
# Saved trajectories to trajectory_data_4\trajectory_0_seed_927.pkl
# Generated and saved state-actions pairs for seed 927
# Saved trajectories to trajectory_data_4\trajectory_0_seed_933.pkl
# Generated and saved state-actions pairs for seed 933
# Saved trajectories to trajectory_data_4\trajectory_0_seed_938.pkl
# Generated and saved state-actions pairs for seed 938
# Saved trajectories to trajectory_data_4\trajectory_0_seed_939.pkl
# Generated and saved state-actions pairs for seed 939
# Saved trajectories to trajectory_data_4\trajectory_0_seed_942.pkl
# Generated and saved state-actions pairs for seed 942
# Saved trajectories to trajectory_data_4\trajectory_0_seed_945.pkl
# Generated and saved state-actions pairs for seed 945
# Saved trajectories to trajectory_data_4\trajectory_0_seed_950.pkl
# Generated and saved state-actions pairs for seed 950
# Saved trajectories to trajectory_data_4\trajectory_0_seed_957.pkl
# Generated and saved state-actions pairs for seed 957
# Saved trajectories to trajectory_data_4\trajectory_0_seed_960.pkl
# Generated and saved state-actions pairs for seed 960
# Saved trajectories to trajectory_data_4\trajectory_0_seed_961.pkl
# Generated and saved state-actions pairs for seed 961
# Saved trajectories to trajectory_data_4\trajectory_0_seed_965.pkl
# Generated and saved state-actions pairs for seed 965
# Saved trajectories to trajectory_data_4\trajectory_0_seed_969.pkl
# Generated and saved state-actions pairs for seed 969
# Saved trajectories to trajectory_data_4\trajectory_0_seed_970.pkl
# Generated and saved state-actions pairs for seed 970
# Saved trajectories to trajectory_data_4\trajectory_0_seed_971.pkl
# Generated and saved state-actions pairs for seed 971
# Saved trajectories to trajectory_data_4\trajectory_0_seed_972.pkl
# Generated and saved state-actions pairs for seed 972
# Saved trajectories to trajectory_data_4\trajectory_0_seed_973.pkl
# Generated and saved state-actions pairs for seed 973
# Saved trajectories to trajectory_data_4\trajectory_0_seed_978.pkl
# Generated and saved state-actions pairs for seed 978
# Saved trajectories to trajectory_data_4\trajectory_0_seed_98.pkl
# Generated and saved state-actions pairs for seed 98
# Saved trajectories to trajectory_data_4\trajectory_0_seed_984.pkl
# Generated and saved state-actions pairs for seed 984
# Saved trajectories to trajectory_data_4\trajectory_0_seed_986.pkl
# Generated and saved state-actions pairs for seed 986
# Saved trajectories to trajectory_data_4\trajectory_0_seed_989.pkl
# Generated and saved state-actions pairs for seed 989
# Saved trajectories to trajectory_data_4\trajectory_0_seed_991.pkl
# Generated and saved state-actions pairs for seed 991
# Saved trajectories to trajectory_data_4\trajectory_0_seed_993.pkl
# Generated and saved state-actions pairs for seed 993
# Saved trajectories to trajectory_data_4\trajectory_0_seed_994.pkl
# Generated and saved state-actions pairs for seed 994
# Saved trajectories to trajectory_data_4\trajectory_0_seed_999.pkl
# Generated and saved state-actions pairs for seed 999

# %%
def generate_and_save_multiple_trajectories(env, num_seeds, start_seed):
    """
    Generate and save multiple trajectories to PKL files
    
    Args:
        env: Gymnasium environment
        num_seeds (int): Number of different seeds to generate
        start_seed (int): Starting seed number
    """
    for seed_idx in range(num_seeds):
        current_seed = start_seed + seed_idx
        
        # Reset environment with new seed
        env.reset(seed=current_seed)
        env_desc = describe_environment(env)
        
        # Get trajectory from LLM and get the state-action pairs
        response = get_trajectory_from_llm(env_desc)
        trajectories = parse_json(response)
        state_action_pairs = simulate_environment(env, current_seed, trajectories)
        
        # Save to PKL file
        save_trajectory_pkl(current_seed, state_action_pairs)
        print(f"Generated and saved state-actions pairs for seed {current_seed}")

# Generate trajectories for 10 different seeds
generate_and_save_multiple_trajectories(env, num_seeds=5, start_seed=6)
# Out:
# Saved trajectories to trajectory_data\trajectories_seed6.pkl
# Generated and saved state-actions pairs for seed 6
# Saved trajectories to trajectory_data\trajectories_seed7.pkl
# Generated and saved state-actions pairs for seed 7
# Saved trajectories to trajectory_data\trajectories_seed8.pkl
# Generated and saved state-actions pairs for seed 8
# Saved trajectories to trajectory_data\trajectories_seed9.pkl
# Generated and saved state-actions pairs for seed 9
# Saved trajectories to trajectory_data\trajectories_seed10.pkl
# Generated and saved state-actions pairs for seed 10
#
# Total trajectories saved: 11
# Seed 0: 17 steps
# Seed 1: 20 steps
# Seed 10: 1 steps
# Seed 2: 26 steps
# Seed 3: 22 steps
# Seed 4: 16 steps
# Seed 5: 14 steps
# Seed 6: 17 steps
# Seed 7: 18 steps
# Seed 8: 10 steps
# Seed 9: 24 steps

# %%
# Verify the saved file
import glob
saved_files = glob.glob('trajectory_data/trajectories_seed*.pkl')
print(f"\nTotal trajectories saved: {len(saved_files)}")
for file in saved_files:
    seed = file.split('seed')[-1].split('.')[0]
    data = load_trajectory(int(seed))
    print(f"Seed {seed}: {data}")
# Out:
# Total trajectories saved: 190
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 7
#       5 for file in saved_files:
#       6     seed = file.split('seed')[-1].split('.')[0]
# ----> 7     data = load_trajectory(int(seed))
#       8     print(f"Seed {seed}: {data}")
#
# NameError: name 'load_trajectory' is not defined
